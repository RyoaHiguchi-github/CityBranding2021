# %% [markdown]
# # 学生_どんな街になってほしいか

# %%
import pandas as pd
import csv
from pprint import pprint
import MeCab
import regex
import re
from collections import Counter

# %%
df = pd.read_csv("../subject/student.csv")
#問16
df16 = df.iloc[:,18:19].dropna(how='all')
df16
# Out:
#                                            問16
# 0                            さらにいい町\n\nカニほしいです
# 1                          教育に力を入れて、子どもにも優しいまち
# 2                     パチンコと喫煙所がない町\n\n育児がしやすい町
# 3                                      活気あふれる町
# 4          飲食店とかをもっと増やして、観光客がきたくなるような町になってほしい。
# ...                                        ...
# 1300                      もっと舞鶴のいいところをアピールすべき。
# 1301                                   市民に愛される
# 1302  交通の便がよく、スタバが豊富にあり、イオンがあり休日に遊びに行きたくなるような町
# 1303                                     おいしい町
# 1305                              便利なまちになってほしい
#
# [1076 rows x 1 columns]

# %%
import MeCab
import regex

class IndependentWord:
    def __init__(self):
        self.m = MeCab.Tagger("-d /usr/local/mecab/lib/mecab/dic/mecab-ipadic-neologd/")
#         self.kanaalpha = regex.compile(r'[\p{Script=Hiragana}\p{Script=Katakana}ーA-Za-z]')
        self.kanaalpha = regex.compile(r'[\p{Script=Hiragana}ーA-Za-z]+')
        self.number = regex.compile('[0-9０-９]+')

    class Constant:
        BASIC = "basic_form" #原型
        SURFACE = "surface_form" #表層型
        POS = "pos" #品詞
        POS_DETAIL_1 = "pos_detail_1" #品詞詳細1
        POS_DETAIL_2 = "pos_detail_2" #品詞詳細2
        POS_DETAIL_3 = "pos_detail_3" #品詞詳細3
        PRONUNCIATION = "pronunciation" #発音
        READING = "reading" #読み
        CONJUGATED_TYPE = "conjugated_type" #活用
        CONJUGATED_FORM = "conjugated_form" #活用形

  #mecabの出力行をobjectに変換
  #mecabの出力フォーマットに応じて適宜修正する
    def mecabLineToDict(self, line):
        surface, tmp = line.split("\t")
        others = tmp.split(",")
    
        Const = self.Constant

        return {
            Const.SURFACE: surface,
            Const.POS: others[0],
            Const.POS_DETAIL_1: others[1],
            Const.POS_DETAIL_2: others[2],
            Const.POS_DETAIL_3: others[3],
            Const.CONJUGATED_TYPE: others[4],
            Const.CONJUGATED_FORM: others[5],
            Const.BASIC: others[6],
            Const.READING: others[7],
            Const.PRONUNCIATION: others[8]
        }
#自立語かどうかの判定
    def isIndependentWord(self, token):
        pos = token[self.Constant.POS]
        pos_detail_1 = token[self.Constant.POS_DETAIL_1]
        if pos == "名詞" and pos_detail_1 in ['一般','固有名詞','サ変接続','形容動詞語幹']: #用途によっては「副詞可能」を足しても良いかもしれません
            return True
        elif pos == '形容詞' and pos_detail_1 == '自立':
            return True
        elif pos == "副詞" and pos_detail_1 == "一般":
            return True
        elif pos == "動詞" and pos_detail_1 == "自立":
            return True
        else:
            return False
        
  #カナやアルファベット１文字や数字出ないかの判定
    def isReliableWord(self, token):
        surface = token[self.Constant.SURFACE]
        if self.number.fullmatch(surface):
            return False
        elif self.kanaalpha.fullmatch(surface):
            return False
        else:
            return True

  #自立語の原型を抽出
    def extract(self,text):
        lines = self.m.parse(text).splitlines()[:-1]
        tokens = [self.mecabLineToDict(line) for line in lines]

        independent_words = []
        for token in tokens:
            if self.isIndependentWord(token) and self.isReliableWord(token):
#             if self.isIndependentWord(token):
                surface = token[self.Constant.SURFACE]
                basic = token[self.Constant.BASIC]
                if basic == "*":
                    independent_words.append(surface)
                else:
                    independent_words.append(basic)
        return independent_words

# %%
#問16
#df["問16"]
df = pd.read_csv("../subject/student.csv")
df16 = df.iloc[:,18:19].dropna(how='all')

list = []
# .replace('','')

for i in df16["問16"]:
    i = re.sub('[0-9.,０-９．，]|[a-zA-Z]|%|~|〜|', '', i)
#     s = i.lstrip('・').replace('/','').replace('(','').replace(')','').replace('\u3000','').replace('TNR','').replace('ー10％','').replace('1H30min~2H','').replace('マイナス30％','').replace('100','').replace('20％','').replace('Society5.0やSDFGs','').replace('R27','')
    s = i.lstrip('・').replace('パーツ','').replace('シャッター','').replace('デコボコ','').replace('ドンキーホーテ','').replace('ブックオフ','').replace('（','').replace('）','').replace('/','').replace('(','').replace(')','').replace('\u3000','').replace('Society5.0','').replace('R27','').replace('ー10％','').replace('1H30min~2H','').replace('~','').replace('-','').replace('%','').replace('･','').replace('!','').replace('ベビカー','').replace('～','').replace('キャンプ','')
    list.append(s)
# print(list)

# 実行
res = []
if __name__ == "__main__":
    for i in list:
        idptwd = IndependentWord()
        result = idptwd.extract(i)
        res.append(result)

# ストップワード
stop = ['街', 'まち', '町', '住む', '人', 'ひと', '舞鶴', '思う']
words = []

for i in res:
    for t in i:
        if t not in stop:
            words.append (t)

# %%
list[len(res):(len(res) + 1)]
# len(res)
# list[372:374]
# Out:
# []

# %%
text = \
'若者から老人までが笑って過ごせる町'

res = []
if __name__ == "__main__":
    idptwd = IndependentWord()
    result = idptwd.extract(text)
    res.append(result)
result
# Out:
# ['若者', '老人', '笑う', '過ごせる', '町']

# %%
result = ' '.join(s for s in words)
result
# Out:
# 'カニ 教育 力 入れる 子ども 優しい パチンコ 喫煙所 育児 活気 飲食店 増やす 観光客 観光 活発 観光客 来る 治安 港町 有名人 訪れる 若者 多い 児童虐待 切実 満足度 活気 観光客 来る 思える 他 自慢 交通 便 良い 都会 自然 残る 高齢者 必要 医療 受ける 若者 子育て 取り組み 環境 配慮 通勤 電車 車両 多い 田舎 地区 バス 少ない 若者 増える 地域 活性 住民 安心 不自由 暮らし 活気 店 増える 電車 走る 都会 都会 田舎 都会 落ちつく 元気 治安 良い 豊か 商店街 栄える 自然 豊か 自然 人々 増える 人と人のつながり 大切 観光客 自然 他 地域 交流 深い 残す 技術 発達 喜多 市長 遊ぶ 多い 有名ブランド 入る デパート 伝統 大切 高齢者 子ども 大切 豊か 自然 残す 楽しい 活気 積極的 取りくむ 自然 豊か 自然 守る 店 増やす 店 老若男女 楽しめる 自然 豊か 歴史的背景 残す 都会 行事 活発 雰囲気 交通 便 良い 豊か 海 山 活かす 自然 欲しい 道路 �
危険 歴史 残る 景色 美しい 自然 豊か 他 都道府県 来る キレイ 住民 人達 協力 幸せ 生きる 自然 残る 有名 平和 活気 不審 少い 平和 建物 素敵 特に 平和 幸せ 空気 ゴミ 活力 人数 少ない 移 注す 都会 笑顔 子供 知る 魚 便利 都会 自然 豊か 若者 施設 若者 過ごす 日本 国民 来る 都会 交通 便 良い 集まる 本 電車 不便 店 多い フルサト インスタ映え 言う 有名 若者 来る 思える 観光地 発展 自然 良い 思える 場所 平和 保つ キレイ ドーム 大きい 映画 イオン 良い 大型 店 増える 色々 県 有名 人達 若い人 遊べる 観光 来る 自然 豊か 自然 豊か 維持 来る 豊か オシャレ 点 盛ん 自然 豊か 治安 良い 自然 大事 楽しい 心 優しい 多い 東京 若い 子 増える 楽しい 好く 物 平和 安全 発展 楽しい 治安 良い 活気 自然 多い 自然 犯罪 笑顔 明るい 都会 観光客 活気 楽しい 開く 来る 魅力的 便利 豊か 笑い 豊か 子供達 遊べる 場所 活力 カニ 下さる お願い 自然 遊ぶ 明るい 楽しい 豊か 人々 思える 観光客 活気 若い人 年 活気 ショッピングモール 欲しい 観光 興味 空気 ポイ捨て 都会 自然 空気 発展 多い 店 商店街 自然 豊か 静か 元気 明るい 遊べる 発展 思いやり 心 店 大きい スーパー デパート 若い 人達 来る 魅力 店 増やす 祭り 増やす 高齢者 子育て 若者 増える 良い 明るい 笑顔 観光 豊か 医療 充実 平和 有名 明るい 犯罪 安心 住める 世代 交流 家族 地域 助け合 ...

# %%
#ワードクラウドの作成
from matplotlib import pyplot as plt
from wordcloud import WordCloud
 
# w = WordCloud(background_color="white", width=600, height=400, min_font_size=15)

wc = WordCloud(
        font_path = "~/Library/Fonts/ヒラギノ角ゴシック W3.ttc",
        width=1920, 
        height=1080,
        prefer_horizontal=1,
        background_color='white',
        include_numbers=True,
        colormap='tab20',
        regexp=r"[\w']+",
    ).generate_from_text(result)

plt.imshow(wc)
plt.axis("off")
plt.show()
wc.to_file('./student_16.png')

# %%
# 頻出単語を出力
mine = Counter(words)
for i in mine.most_common():
    print(i)

# values, counts = zip(*mine.most_common())
# values
# counts
# Out:
# ('自然', 88)
# ('豊か', 64)
# ('都会', 51)
# ('活気', 49)
# ('多い', 46)
# ('良い', 45)
# ('店', 44)
# ('楽しい', 39)
# ('交通', 37)
# ('来る', 32)
# ('若者', 31)
# ('増える', 28)
# ('観光客', 26)
# ('便利', 26)
# ('発展', 25)
# ('観光', 23)
# ('平和', 23)
# ('便', 22)
# ('明るい', 22)
# ('安全', 20)
# ('場所', 20)
# ('増やす', 19)
# ('思える', 19)
# ('残す', 19)
# ('優しい', 16)
# ('電車', 16)
# ('子ども', 14)
# ('高齢者', 14)
# ('安心', 14)
# ('遊ぶ', 13)
# ('海', 13)
# ('若い人', 13)
# ('有名', 13)
# ('充実', 13)
# ('大切', 12)
# ('楽しめる', 11)
# ('特に', 11)
# ('治安', 10)
# ('商店街', 10)
# ('人口', 10)
# ('思いやり', 2)
# ('人気', 2)
# ('聞く', 2)
# ('守れる', 2)
# ('支える', 2)
# ('合える', 2)
# ('ポイ捨て', 2)
# ('学生', 2)
# ('整う', 2)
# ('感じ', 2)
# ('古い', 2)
# ('観光業', 2)
# ('進学', 2)
# ('開く', 2)
# ('京都', 2)
# ('分かる', 2)
# ('自衛隊', 2)
# ('活用', 2)
# ('風景', 2)
# ('公共交通機関', 2)
# ('取り入れる', 2)
# ('魚', 2)
# ('高位', 2)
# ('ビル', 2)
# ('遊び', 2)
# ('暮', 2)
# ('都市化', 2)
# ('商業', 2)
# ('含む', 2)
# ('ご飯', 2)
# ('歩き', 2)
# ('感じる', 2)
# ('交通機関', 2)
# ('通り', 2)
# ('不審', 2)
# ('活力', 2)
# ('本', 2)
# ('大型', 2)
# ('県', 2)
# ('心', 2)
# ('若い', 2)
# ('家族', 2)
# ('家', 2)
# ('通る', 2)
# ('駅', 2)
# ('有料', 2)
# ('スペース', 2)
# ('活気づく', 2)
# ('進む', 2)
# ('問う', 2)
# ('大好き', 2)
# ('PR', 2)
# ('心地', 2)
# ('京都府', 2)
# ('壊す', 2)
# ('中心', 2)
# ('少子高齢化', 2)
# ('住', 2)
# ('毎日', 2)
# ('病院', 2)
# ('床', 2)
# ('行う', 2)
# ('船', 2)
# ('パチンコ', 1)
# ('喫煙所', 1)
# ('育児', 1)
# ('港町', 1)
# ('有名人', 1)
# ('児童虐待', 1)
# ('切実', 1)
# ('満足度', 1)
# ('自慢', 1)
# ('必要', 1)
# ('取り組み', 1)
# ('配慮', 1)
# ('通勤', 1)
# ('車両', 1)
# ('地区', 1)
# ('暮らし', 1)
# ('走る', 1)
# ('人と人のつながり', 1)
# ('深い', 1)
# ('喜多', 1)
# ('市長', 1)
# ('有名ブランド', 1)
# ('積極的', 1)
# ('取りくむ', 1)
# ('歴史的背景', 1)
# ('道路', 1)
# ('歩道', 1)
# ('コンビニ', 1)
# ('言える', 1)
# ('記憶', 1)
# ('外国人', 1)
# ('公園', 1)
# ('変', 1)
# ('適度', 1)
# ('美味しい', 1)
# ('経済', 1)
# ('完結', 1)
# ('残れる', 1)
# ('長い', 1)
# ('老齢', 1)
# ('溢れる', 1)
# ('出会い', 1)
# ('大人', 1)
# ('平等', 1)
# ('お金', 1)
# ('盛り上げる', 1)
# ('盛り上がる', 1)
# ('伝統的', 1)
# ('追加', 1)
# ('アニメイト', 1)
# ('落ちる', 1)
# ('多国籍', 1)
# ('板ガラス', 1)
# ('職業', 1)
# ('関わる', 1)
# ('機械', 1)
# ('近づける', 1)
# ('アリオ', 1)
# ('仲', 1)
# ('出入り', 1)
# ('穏やか', 1)
# ('西', 1)
# ('テニスコート', 1)
# ('乍', 1)
# ('開発', 1)
# ('住民票', 1)
# ('移す', 1)
# ('続ける', 1)
# ('集める', 1)
# ('草', 1)
# ('全国', 1)
# ('使える', 1)
# ('寄る', 1)
# ('似る', 1)
# ('年令', 1)
