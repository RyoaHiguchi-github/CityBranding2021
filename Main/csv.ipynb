# %%
import pandas as pd
import csv
from pprint import pprint
import MeCab
import regex
from collections import Counter

# %%
# コンストラクタと形態素解析
class IndependentWord:
    def __init__(self, dictpath="/usr/local/mecab/lib/mecab/dic/mecab-ipadic-neologd/"):
        if dictpath:
            self.m = MeCab.Tagger("-d"+dictpath)
            
        else:
            self.m = MeCab.Tagger()   
#         self.kanaalpha = regex.compile(r'[\p{Script=Hiragana}\p{Script=Katakana}ーA-Za-z]+')
        self.kanaalpha = regex.compile(r'[\p{Script=Hiragana}ーA-Za-z]+')
        self.number = regex.compile("[0-9０-９]+")
    class Constant:
        BASIC = "basic_form" #原型
        SURFACE = "surface_form" #表層型
        POS = "pos" #品詞
        POS_DETAIL_1 = "pos_detail_1" #品詞詳細1
        POS_DETAIL_2 = "pos_detail_2" #品詞詳細2
        POS_DETAIL_3 = "pos_detail_3" #品詞詳細3
        PRONUNCIATION = "pronunciation" #発音
        READING = "reading" #読み
        CONJUGATED_TYPE = "conjugated_type" #活用
        CONJUGATED_FORM = "conjugated_form" #活用形

  #mecabの出力行をobjectに変換
  #mecabの出力フォーマットに応じて適宜修正する
    def mecabLineToDict(self, line):
        surface, tmp = line.split("\t")
        others = tmp.split(",")
        
        Const = self.Constant
        return {
            Const.SURFACE: surface,
            Const.POS: others[0],
            Const.POS_DETAIL_1: others[1],
            Const.POS_DETAIL_2: others[2],
            Const.POS_DETAIL_3: others[3],
            Const.CONJUGATED_TYPE: others[4],
            Const.CONJUGATED_FORM: others[5],
            Const.BASIC: others[6],
            Const.READING: others[7],
            Const.PRONUNCIATION: others[8]
        }
  #自立語かどうかの判定
    def isIndependentWord(self, token):
        pos = token[self.Constant.POS]
        pos_detail_1 = token[self.Constant.POS_DETAIL_1]
        if pos == "名詞" and pos_detail_1 in ['一般','固有名詞','サ変接続','形容動詞語幹','副詞可能']: #用途によっては「副詞可能」を足しても良いかもしれません
            return True
        elif pos == '形容詞' and pos_detail_1 == '自立':
            return True
        elif pos == "副詞" and pos_detail_1 == "一般":
            return True
        elif pos == "動詞" and pos_detail_1 == "自立":
            return True
        else:
            return False
  #カナやアルファベット１文字や数字出ないかの判定
    def isReliableWord(self, token):
        surface = token[self.Constant.SURFACE]
        if self.number.fullmatch(surface):
            return False
        elif self.kanaalpha.fullmatch(surface):
            return False
        else:
            return True

  #自立語の原型を抽出
    def extract(self,text):
        lines = self.m.parse(text).splitlines()[:-1]
        tokens = [self.mecabLineToDict(line) for line in lines]

        independent_words = []
        for token in tokens:
#             if self.isIndependentWord(token):
            if self.isIndependentWord(token) and self.isReliableWord(token):
                surface = token[self.Constant.SURFACE]
                basic = token[self.Constant.BASIC]
                if basic == "*":
                    independent_words.append(surface)
                else:
                    independent_words.append(basic)
                    
        return independent_words

# %% [markdown]
# # 一般市民_心豊かに暮らせるまちづくり

# %%
df = pd.read_csv("../一般市民/舞鶴市_一般市民_1.csv")
list = []
for i in df['一般市民']:
    s = i.lstrip('・').replace('(','').replace(')','').replace('\u3000','').replace('TNR','')
    list.append(s)

# 実行
res = []
if __name__ == "__main__":
    for i in list:
        idptwd = IndependentWord()
        result = idptwd.extract(i)
        res.append(result)
        
# ストップワード
stop = ['街', 'まち', '町', '住む', '人', 'ひと', '舞鶴', '思う']
words = []

for i in res:
    for t in i:
        if t not in stop:
            words.append (t)

#頻出単語を出力
mine = Counter(words)
for i in mine.most_common():
    print(i)
# Out:
# ('自然', 26)
# ('明るい', 21)
# ('豊か', 18)
# ('元気', 17)
# ('歴史', 17)
# ('子ども', 16)
# ('楽しい', 15)
# ('優しい', 14)
# ('田舎', 12)
# ('暮らす', 12)
# ('良い', 12)
# ('暮らせる', 12)
# ('地域', 11)
# ('今', 11)
# ('増える', 11)
# ('文化', 11)
# ('子供達', 11)
# ('来る', 11)
# ('場所', 11)
# ('大切', 10)
# ('魅力', 10)
# ('心', 9)
# ('多い', 9)
# ('安心', 9)
# ('市', 8)
# ('思える', 8)
# ('美しい', 7)
# ('笑顔', 7)
# ('芸術', 7)
# ('海', 7)
# ('交流', 7)
# ('世代', 7)
# ('年齢', 7)
# ('過ごせる', 7)
# ('方々', 7)
# ('持つ', 7)
# ('市民', 6)
# ('楽しめる', 6)
# ('都会', 6)
# ('教育', 6)
# ('年寄り', 6)
# ('高齢者', 6)
# ('作る', 6)
# ('考える', 6)
# ('施設', 6)
# ('知る', 6)
# ('温かい', 5)
# ('仲良く', 5)
# ('生活', 5)
# ('幸せ', 5)
# ('北部', 5)
# ('子供', 5)
# ('残す', 5)
# ('充実', 5)
# ('自分', 5)
# ('感じる', 5)
# ('遊べる', 5)
# ('良さ', 5)
# ('仕事', 5)
# ('医療', 5)
# ('居心地', 4)
# ('暖かい', 4)
# ('面白い', 4)
# ('若い人', 4)
# ('思いやり', 4)
# ('舞鶴市民', 4)
# ('人達', 4)
# ('力', 4)
# ('舞鶴市', 4)
# ('気持ち', 4)
# ('生きる', 4)
# ('発展', 4)
# ('嬉しい', 4)
# ('進む', 4)
# ('山', 4)
# ('言葉', 4)
# ('市外', 4)
# ('地元', 4)
# ('年配', 4)
# ('様々', 4)
# ('持てる', 4)
# ('文化的', 3)
# ('元気な町', 3)
# ('住民', 3)
# ('溢れる', 3)
# ('静か', 3)
# ('吹奏楽', 3)
# ('大事', 3)
# ('人々', 3)
# ('京都', 3)
# ('楽しみ', 3)
# ('一人一人', 3)
# ('環境', 3)
# ('残る', 3)
# ('高い', 3)
# ('若い世代', 3)
# ('若者', 3)
# ('日本海', 3)
# ('年', 3)
# ('将来', 3)
# ('大人', 3)
# ('外', 3)
# ('考え', 3)
# ('言える', 3)
# ('感じ', 3)
# ('新しい', 3)
# ('誇り', 3)
# ('制度', 3)
# ('京都府', 3)
# ('願う', 3)
# ('学校', 3)
# ('体験', 3)
# ('行く', 3)
# ('高齢', 3)
# ('親', 3)
# ('必要', 3)
# ('伝える', 3)
# ('機会', 3)
# ('夢', 2)
# ('愛す', 2)
# ('孫', 2)
# ('住める', 2)
# ('未来', 2)
# ('自立', 2)
# ('声', 2)
# ('助ける', 2)
# ('素敵', 2)
# ('家族', 2)
# ('高位', 2)
# ('助け合える', 2)
# ('環境に優しい', 2)
# ('尊重', 2)
# ('意味', 2)
# ('年老いる', 2)
# ('思いやる', 2)
# ('穏やか', 2)
# ('支える', 2)
# ('街並み', 2)
# ('全世代', 2)
# ('暮らし', 2)
# ('満足', 2)
# ('入れる', 2)
# ('印象', 2)
# ('音楽', 2)
# ('夏', 2)
# ('冬', 2)
# ('存在', 2)
# ('美味しい', 2)
# ('西', 2)
# ('東', 2)
# ('懐', 2)
# ('居る', 2)
# ('伝統', 2)
# ('移住', 2)
# ('促進', 2)
# ('古記', 2)
# ('助け合う', 2)
# ('働く', 2)
# ('過ごす', 2)
# ('出し手', 2)
# ('大好き', 2)
# ('北近畿', 2)
# ('図書館', 2)
# ('大学', 2)
# ('福祉', 2)
# ('高齢化', 2)
# ('全員', 2)
# ('古い', 2)
# ('町並み', 2)
# ('深い', 2)
# ('合わせる', 2)
# ('変化', 2)
# ('他県', 2)
# ('多様', 2)
# ('地区', 2)
# ('出来る', 2)
# ('交通', 2)
# ('友達', 2)
# ('失う', 2)
# ('取り入れる', 2)
# ('全て', 2)
# ('訪れる', 2)
# ('負ける', 2)
# ('多様性', 2)
# ('設計', 2)
# ('育つ', 2)
# ('問う', 2)
# ('全国', 2)
# ('老人', 2)
# ('治安', 2)
# ('勉強', 2)
# ('伸ばす', 2)
# ('行政', 2)
# ('楽しむ', 2)
# ('敦賀市', 2)
# ('軍港', 2)
# ('少子高齢化', 2)
# ('乏しい', 2)
# ('目立つ', 2)
# ('移住者', 2)
# ('若い', 2)
# ('雰囲気', 2)
# ('止まる', 2)
# ('格差', 2)
# ('無くす', 2)
# ('プラス', 2)
# ('育成', 2)
# ('言う', 2)
# ('関心', 2)
# ('定住', 2)
# ('見える', 2)
# ('特産', 2)
# ('子育て', 2)
# ('花', 2)
# ('積極', 2)
# ('病気', 2)
# ('負担', 2)
# ('個人', 2)
# ('不安', 2)
# ('少ない', 2)
# ('若い人たち', 2)
# ('推進', 2)
# ('欲しい', 2)
# ('教わる', 2)
# ('何とか', 2)
# ('自身', 2)
# ('イメージ', 2)
# ('好き', 2)
# ('広い', 2)
# ('近所', 2)
# ('舞鶴市内', 2)
# ('場', 2)
# ('車', 2)
# ('祖父母', 2)
# ('使う', 2)
# ('異世代', 2)
# ('2点', 2)
# ('前向き', 2)
# ('広報', 2)
# ('居住', 2)
# ('北海道', 2)
# ('開ける', 1)
# ('人柄', 1)
# ('アート', 1)
# ('栄える', 1)
# ('人間関係', 1)
# ('オープン', 1)
# ('クリア', 1)
# ('微笑む', 1)
# ('協同', 1)
# ('一つ', 1)
# ('普通', 1)
# ('共に', 1)
# ('誇れる', 1)
# ('物心', 1)
# ('質', 1)
# ('柔軟性', 1)
# ('人権', 1)
# ('変わる', 1)
# ('落ち着く', 1)
# ('緑', 1)
# ('法律', 1)
# ('変更', 1)
# ('隅々', 1)
# ('行き渡る', 1)
# ('リモート', 1)
# ('〇〇', 1)
# ('趣味', 1)
# ('分野', 1)
# ('スケートリンク', 1)
# ('観覧', 1)
# ('誘致', 1)
# ('生き甲斐', 1)
# ('有る', 1)
# ('応じる', 1)
# ('知育', 1)
# ('運転免許', 1)
# ('憩', 1)
# ('屋根', 1)
# ('ベンチ', 1)
# ('所', 1)
# ('処', 1)
# ('等', 1)
# ('引き揚げる', 1)
# ('迎え入れる', 1)
# ('新た', 1)
# ('作れる', 1)
# ('応援', 1)
# ('貴重', 1)
# ('正しい', 1)
# ('評価', 1)
# ('特別', 1)
# ('有名', 1)
# ('安全', 1)
# ('周囲', 1)
# ('中核', 1)
# ('船旅', 1)
# ('地元住民', 1)
# ('古', 1)
# ('京都市', 1)
# ('最新', 1)
# ('漁村', 1)
# ('里山', 1)
# ('過疎化', 1)
# ('荒れる', 1)
# ('空き地', 1)
# ('敬う', 1)
# ('知恵', 1)
# ('後世', 1)
# ('コンビニ', 1)
# ('豪華客船', 1)
# ('客', 1)
# ('宛', 1)
# ('気の毒', 1)
# ('伝統文化', 1)
# ('継承', 1)
# ('遠方', 1)
# ('友人', 1)
# ('知人', 1)
# ('案内', 1)
# ('暗い', 1)
# ('グレー', 1)
# ('マイナスイメージ', 1)
# ('資源', 1)
# ('集まる', 1)
# ('地方都市', 1)
# ('創', 1)
# ('食', 1)
# ('差別化', 1)
# ('集る', 1)
# ('物', 1)
# ('覚悟', 1)
# ('佐波賀', 1)
# ('万願寺甘とう', 1)
# ('調理', 1)
# ('家出', 1)
# ('甘党', 1)
# ('肉', 1)
# ('自分自身', 1)
# ('出生率', 1)
# ('高め', 1)
# ('完成', 1)
# ('自分たち', 1)
# ('工夫', 1)
# ('進学', 1)
# ('インテリ', 1)
# ('根付く', 1)
# ('違う', 1)
# ('立場', 1)
# ('願い', 1)
# ('耳', 1)
# ('一緒', 1)
# ('お父さん', 1)
# ('お母さん', 1)
# ('コロナ', 1)
# ('希薄', 1)
# ('孤独', 1)
# ('一人', 1)
# ('悩む', 1)
# ('周り', 1)
# ('頼る', 1)
# ('前面', 1)
# ('一緒に', 1)
# ('盛り上げる', 1)
# ('宝物', 1)
# ('育む', 1)
# ('最高', 1)
# ('変わり者', 1)
# ('アーティスト', 1)
# ('芸術系', 1)
# ('伝統工芸', 1)
# ('生み出す', 1)
# ('不便', 1)
# ('自由', 1)
# ('身動き', 1)
# ('引き揚げ', 1)
# ('浮島丸事件', 1)
# ('国際化', 1)
# ('国', 1)
# ('他国', 1)
# ('話す', 1)
# ('恥ずかしい', 1)
# ('美点', 1)
# ('戦前', 1)
# ('戦中', 1)
# ('戦後', 1)
# ('厳しさ', 1)
# ('戒め', 1)
# ('有理', 1)
# ('分かる', 1)
# ('両親', 1)
# ('張り合う', 1)
# ('四字熟語', 1)
# ('童話', 1)
# ('難しい', 1)
# ('会話', 1)
# ('出る', 1)
# ('驚く', 1)
# ('核家族', 1)
# ('現代', 1)
# ('活力', 1)
# ('両方', 1)
# ('得る', 1)
# ('以前', 1)
# ('健康寿命', 1)
# ('健康診断', 1)
# ('病院', 1)
# ('会場', 1)
# ('町内', 1)
# ('公会堂', 1)
# ('小学校', 1)
# ('1回', 1)
# ('乳児', 1)
# ('除く', 1)
# ('簡単', 1)
# ('チェック', 1)
# ('誘い合う', 1)
# ('行ける', 1)
# ('兼ねる', 1)
# ('老後', 1)
# ('希望', 1)
# ('一点', 1)
# ('身', 1)
# ('包み込む', 1)
# ('縁', 1)
# ('生まれる', 1)
# ('貢献', 1)
# ('思い', 1)
# ('進路', 1)
# ('選択', 1)
# ('安定', 1)
# ('体制', 1)
# ('バリアフリー', 1)
# ('見る', 1)
# ('出せる', 1)
# ('憩い', 1)
# ('定期', 1)
# ('絶やす', 1)
# ('支援', 1)
# ('観光', 1)
# ('事業', 1)
# ('下町', 1)
# ('今日', 1)
# ('方面', 1)
# ('観光業界', 1)
# ('注目', 1)
# ('ホームページ', 1)
# ('機能', 1)
# ('席巻', 1)
# ('福知山市', 1)
# ('京丹後市', 1)
# ('発信', 1)
# ('勿論', 1)
# ('ターゲット', 1)
# ('盛り上がる', 1)
# ('廃れる', 1)
# ('活躍', 1)
# ('勢い', 1)
# ('絶える', 1)
# ('大変', 1)
# ('設置', 1)
# ('フェリー', 1)
# ('活用', 1)
# ('学生', 1)
# ('呼び込む', 1)
# ('ミニバス', 1)
# ('路線', 1)
# ('拡充', 1)
# ('運転', 1)
# ('軽減', 1)

# %%
#ワードクラウドの作成
from matplotlib import pyplot as plt
from wordcloud import WordCloud
 
# fpath = "/Library/Fonts/ヒラギノ角ゴシック W3.ttc"
w = WordCloud(background_color="white", width=600, height=400, min_font_size=15)
w.generate(words)
 
# wordcloud.to_file("./wordcloud.png")
plt.imshow(W)
plt.axis('off')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/km/jkkq67dd65b3h3yb86y18ncm0000gn/T/ipykernel_6418/2344192523.py in <module>
#       5 # fpath = "/Library/Fonts/ヒラギノ角ゴシック W3.ttc"
#       6 w = WordCloud(background_color="white", width=600, height=400, min_font_size=15)
# ----> 7 w.generate(words)
#       8
#       9 # wordcloud.to_file("./wordcloud.png")
#
# ~/Library/Python/3.8/lib/python/site-packages/wordcloud/wordcloud.py in generate(self, text)
#     630         self
#     631         """
# --> 632         return self.generate_from_text(text)
#     633
#     634     def _check_generated(self):
#
# ~/Library/Python/3.8/lib/python/site-packages/wordcloud/wordcloud.py in generate_from_text(self, text)
#     611         self
#     612         """
# --> 613         words = self.process_text(text)
#     614         self.generate_from_frequencies(words)
#     615         return self
#
# ~/Library/Python/3.8/lib/python/site-packages/wordcloud/wordcloud.py in process_text(self, text)
#     573         regexp = self.regexp if self.regexp is not None else pattern
#     574
# --> 575         words = re.findall(regexp, text, flags)
#     576         # remove 's
#     577         words = [word[:-2] if word.lower().endswith("'s") else word
#
# /Library/Developer/CommandLineTools/Library/Frameworks/Python3.framework/Versions/3.8/lib/python3.8/re.py in findall(pattern, string, flags)
#     237
#     238     Empty matches are included in the result."""
# --> 239     return _compile(pattern, flags).findall(string)
#     240
#     241 def finditer(pattern, string, flags=0):
#
# TypeError: expected string or bytes-like object

# %%
df = pd.read_csv("~/class_submit/舞鶴市/subject/people.csv")
